# %%
#Import all the functions from the files
from poke_cards_funcs_v5 import *
from poke_product_funcs_v1 import *

# %% [markdown]
# # **<font color='green'>Card Functions Example</font>**

# %%
###ONLY NEED TO RUN THIS ONCE IF YOU KEEP USING SAME CSV FILE
new_pokemon_df('example_pokemon_cards')

# %% [markdown]
# ------
#
# For the first example I add Maractus #160 from Journey Together. The url is:
#  -  https://www.pricecharting.com/game/pokemon-journey-together/maractus-160
#
# The second card I add is Blaziken #192 from Destined Rivals. The url is:
# - https://www.pricecharting.com/game/pokemon-destined-rivals/blaziken-192
#
# The third card I add is Blaziken #192 from Destined Rivals. The url is:
# - hhttps://www.pricecharting.com/game/pokemon-shrouded-fable/kingdra-ex-stamped-12
#
# ------

# %%
df_pokemon_cards = update_poke_df('example_pokemon_cards.csv')
# Out:
# Enter URL or Card Name -  https://www.pricecharting.com/game/pokemon-shrouded-fable/kingdra-ex-stamped-12
# Entering add_card function:
#
# Kingdra EX [Stamped] #12 from Pokemon Shrouded Fable is not present in the 'Card_Names' column. Adding card:
# Couldn't convert PSA 10 price to float.
# Card Name: Kingdra EX [Stamped] #12
# Set Name: Pokemon Shrouded Fable
# Url: https://www.pricecharting.com/game/pokemon-shrouded-fable/kingdra-ex-stamped-12
# Ungraded Price: $1.99
# PSA 10 Price: $nan

# %%
df_pokemon_cards
# Out:
#                   Card_Name                  Set_Name  \
# 0             Maractus #160  Pokemon Journey Together
# 1             Blaziken #192   Pokemon Destined Rivals
# 2  Kingdra EX [Stamped] #12    Pokemon Shrouded Fable
#
#                                                  url  ungraded_price  \
# 0  https://www.pricecharting.com/game/pokemon-jou...            2.69
# 1  https://www.pricecharting.com/game/pokemon-des...            9.10
# 2  https://www.pricecharting.com/game/pokemon-shr...            1.99
#
#    PSA10_price grade_yn  quantity
# 0        36.95       No         1
# 1        99.72      Yes         1
# 2          NaN       No         1

# %% [markdown]
# -----
#
# Next I use the multi-update function. Nothing is needed to do except run the line.

# %%
df_pokemon_cards = multi_update_poke_df('example_pokemon_cards.csv')
# Out:
# Card Name: Maractus #160
# Url: https://www.pricecharting.com/game/pokemon-journey-together/maractus-160
#
# Card Name: Blaziken #192
# Url: https://www.pricecharting.com/game/pokemon-destined-rivals/blaziken-192
#
# Couldn't convert PSA 10 price to float.
# Card Name: Kingdra EX [Stamped] #12
# Url: https://www.pricecharting.com/game/pokemon-shrouded-fable/kingdra-ex-stamped-12

# %% [markdown]
# -----
#
# Then I remove the Kingra card. I simply copy and paste the name from the `Card_Name` column (Kingdra EX [Stamped] #12). However you could have also put the number 2, the index.

# %%
df_pokemon_cards = remove_card('example_pokemon_cards.csv')
# Out:
# Enter the card name or row index to delete:  2
# Dropping card 'Kingdra EX [Stamped] #12' at index 2
# Saving csv file.

# %%
df_pokemon_cards
# Out:
#        Card_Name                  Set_Name  \
# 0  Maractus #160  Pokemon Journey Together
# 1  Blaziken #192   Pokemon Destined Rivals
#
#                                                  url  ungraded_price  \
# 0  https://www.pricecharting.com/game/pokemon-jou...            2.69
# 1  https://www.pricecharting.com/game/pokemon-des...            9.10
#
#    PSA10_price grade_yn  quantity
# 0        36.95       No         1
# 1        99.72      Yes         1

# %% [markdown]
# -----
#
# Notice We have quantities for each card. This is to help keep track if you have multiple instances of the card in your collection. Let's see an example where you try to add a card in your collection already.

# %%
df_pokemon_cards = update_poke_df('example_pokemon_cards.csv')
# Out:
# Enter URL or Card Name -  https://www.pricecharting.com/game/pokemon-journey-together/maractus-160
# Entering add_card function:
#
# Maractus #160 from Pokemon Journey Together is present in spreadsheet.
# Would you like to:
# 1. Update price?
# 2. Update quantity?
#  2
# You currently have 1 of these cards.
# Would you like to:
# 1.Add one?
# 2.Update manually?
#  1

# %%
df_pokemon_cards
# Out:
#        Card_Name                  Set_Name  \
# 0  Maractus #160  Pokemon Journey Together
# 1  Blaziken #192   Pokemon Destined Rivals
#
#                                                  url  ungraded_price  \
# 0  https://www.pricecharting.com/game/pokemon-jou...            2.69
# 1  https://www.pricecharting.com/game/pokemon-des...            9.10
#
#    PSA10_price grade_yn  quantity
# 0        36.95       No         2
# 1        99.72      Yes         1

# %% [markdown]
# We note that two pop-up options appear. We can either update the price or update the quantity. If you choose to update the quantity, it will ask if you simply want to add one more to your collection or update the number manually (say you add 3 more so the total is 4).
#
# ------

# %% [markdown]
# ### Version 5 Update:
#
# I have added two new user functions for you to update the price or quantity of a single card. Below are the function names and how to use them.

# %%
df_pokemon_cards = user_update_quantity('example_pokemon_cards.csv')
# Out:
# Enter row index to update quantity:  1
# Updating card: Blaziken #192 from Pokemon Destined Rivals. You currently have 1.
# How many do you own now? -  11
# Saving csv file.

# %%
df_pokemon_cards
# Out:
#        Card_Name                  Set_Name  \
# 0  Maractus #160  Pokemon Journey Together
# 1  Blaziken #192   Pokemon Destined Rivals
#
#                                                  url  ungraded_price  \
# 0  https://www.pricecharting.com/game/pokemon-jou...            2.69
# 1  https://www.pricecharting.com/game/pokemon-des...            9.10
#
#    PSA10_price grade_yn  quantity
# 0        36.95       No         2
# 1        99.72      Yes        11

# %%
df_pokemon_cards = user_update_price('example_pokemon_cards.csv')
# Out:
# Enter row index to update quantity:  1
# Updating card price: Blaziken #192 from Pokemon Destined Rivals.
# Card Name: Blaziken #192
# Url: https://www.pricecharting.com/game/pokemon-destined-rivals/blaziken-192
# Updated Ungraded Price: $9.1
# Updated PSA 10 Price: $99.72

# %% [markdown]
# # **<font color='blue'>Product Functions Example</font>**

# %%
###ONLY NEED TO RUN THIS ONCE IF YOU KEEP USING SAME CSV FILE
new_pokemon_products_df('example_inventory_pokemon')

# %% [markdown]
# -----
#
# For the first example I add is a Phantasmal Flames Pokemon Center ETB. The url is:
#  -  https://www.pricecharting.com/game/pokemon-phantasmal-flames/elite-trainer-box-pokemon-center
#
# The second product I add is a 151 booster bundle. The url is:
# - https://www.pricecharting.com/game/pokemon-scarlet-&-violet-151/booster-bundle
#
# -----

# %%
inven_df = update_poke_prod_df('example_inventory_pokemon.csv')
# Out:
# Enter URL -  https://www.pricecharting.com/game/pokemon-scarlet-&-violet-151/booster-bundle
# Entering add_product function:
#
# Booster Bundle from Pokemon Scarlet & Violet 151 is not present in the 'Product_Name' column. Adding product:
# What is the MSRP? -  26.94
# How many do you own? -  2
# Url: https://www.pricecharting.com/game/pokemon-scarlet-&-violet-151/booster-bundle
# Market Price: 88.5
# Quantity: 2

# %%
inven_df
# Out:
#                          Product_Name                      Set_Name  \
# 0  Elite Trainer Box [Pokemon Center]     Pokemon Phantasmal Flames
# 1                      Booster Bundle  Pokemon Scarlet & Violet 151
#
#                                                  url   MSRP  market_price  \
# 0  https://www.pricecharting.com/game/pokemon-pha...  59.99        188.52
# 1  https://www.pricecharting.com/game/pokemon-sca...  26.94         88.50
#
#    quantity
# 0        10
# 1         2

# %% [markdown]
# -----
#
# Next I use the multi-update function. Nothing is needed to do except run the line.
#
# ----

# %%
inven_df = multi_update_price_poke_product_df('example_inventory_pokemon.csv')
# Out:
# Url: https://www.pricecharting.com/game/pokemon-phantasmal-flames/elite-trainer-box-pokemon-center
# Market Price: 188.52
#
# Url: https://www.pricecharting.com/game/pokemon-scarlet-&-violet-151/booster-bundle
# Market Price: 88.5

# %% [markdown]
# ------
#
# Next I update how many Phantasmal Flames ETBs I have. I changed it to 5 now instead of 10.
#
# ----

# %%
inven_df = update_quant_prod('example_inventory_pokemon.csv')
# Out:
# Enter row index to update quantity:  0
# Updating product: Elite Trainer Box [Pokemon Center] from Pokemon Phantasmal Flames
# How many do you own now? -  5
# Saving csv file.

# %%
inven_df
# Out:
#                          Product_Name                      Set_Name  \
# 0  Elite Trainer Box [Pokemon Center]     Pokemon Phantasmal Flames
# 1                      Booster Bundle  Pokemon Scarlet & Violet 151
#
#                                                  url   MSRP  market_price  \
# 0  https://www.pricecharting.com/game/pokemon-pha...  59.99        188.52
# 1  https://www.pricecharting.com/game/pokemon-sca...  26.94         88.50
#
#    quantity
# 0         5
# 1         2
